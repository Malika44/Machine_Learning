# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
X = np.random.randint(0, 100, size=10)
y = np.random.normal() * X + 5 + np.random.randint(0, 10) * X
y[6] = y[6] + 10
y[3] = y[3] + -10
y[7] = y[3] + -30

# %%
plt.scatter(X, y, marker="+")

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X.reshape(-1, 1), y.reshape(-1, 1))
# Out:
# LinearRegression()

# %%
new_X = np.linspace(X.min(), X.max(), 100)
y_hat = model.predict(new_X.reshape(-1, 1))

# %%
plt.scatter(X, y, color="red",marker="+")
plt.plot(new_X, y_hat)

# %% [markdown]
# # OPEN Q: How to evaluate the ML model skill?
# # How the Learning Algorhtim knows the best fit line (in the case of LR)
